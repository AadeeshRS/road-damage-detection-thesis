# %%
from ultralytics import YOLO
import os
import yaml
import shutil
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 95.4 MB/s eta 0:00:00:00:010:01
# ...
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
dataset_yaml = """
path: /kaggle/input/datasets/aliabdelmenam/rdd-2022/RDD_SPLIT

train: train/images
val: val/images
test: test/images

names:
  0: longitudinal crack
  1: transverse crack
  2: alligator crack
  3: other corruption
  4: pothole
"""

with open("dataset.yaml", "w") as f:
    f.write(dataset_yaml)

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.train(
    data="dataset.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    device=0,
    project="runs/detect",
    name="yolov11n_baseline",
    seed=42,
    pretrained=True
)
# Out:
# Ultralytics 8.4.83 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# ...

# %%
# !zip -r yolov11n_results.zip /kaggle/working/runs/detect/runs/detect/yolov11n_baseline
# Out:
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/ (stored 0%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/confusion_matrix_normalized.png (deflated 20%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/labels.jpg (deflated 18%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/val_batch1_pred.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/val_batch0_labels.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/val_batch2_labels.jpg (deflated 10%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/BoxP_curve.png (deflated 8%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/results.csv (deflated 59%)
#   adding: kaggle/working/runs/detect/runs/detect/yolov11n_baseline/val_batch2_pred.jpg (deflated 10%)
# ...
