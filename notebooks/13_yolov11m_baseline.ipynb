# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.0 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO
import os
import yaml
import shutil
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
dataset_yaml = """
path: /kaggle/input/datasets/aliabdelmenam/rdd-2022/RDD_SPLIT

train: train/images
val: val/images
test: test/images

names:
  0: longitudinal crack
  1: transverse crack
  2: alligator crack
  3: other corruption
  4: pothole
"""

with open("dataset.yaml", "w") as f:
    f.write(dataset_yaml)

# %%
model = YOLO("yolo11m.pt")

# %%
results = model.train(
    data="dataset.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    device=0,
    project="runs/detect",
    name="yolov11m_baseline",
    seed=42,
    pretrained=True
)
# Out:
# Ultralytics 8.4.86 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# ...

# %%
# !zip -r yolov11m_results.zip /kaggle/working/runs/detect/runs/detect/yolov11m_baseline
from IPython.display import FileLink
FileLink(r'yolov11m_results.zip')
# Out:
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/ (stored 0%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/BoxF1_curve.png (deflated 9%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/train_batch16802.jpg (deflated 8%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/val_batch1_labels.jpg (deflated 8%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/confusion_matrix_normalized.png (deflated 20%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/results.csv (deflated 60%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/results.png (deflated 7%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/val_batch0_labels.jpg (deflated 9%)
# updating: kaggle/working/runs/detect/runs/detect/yolov11m_baseline/val_batch1_pred.jpg (deflated 8%)
# ...
